# %%
import pandas as pd
import json

# %%
with open(r'C:\Users\USER\Desktop\Programming\Python\Personal_Projects\Anime Royale Wiki\ar_wiki\data\cleaned_data\maps.json', 'r') as f:
    item_data = json.load(f)

# %%
df = pd.DataFrame.from_dict(item_data, orient="index")
df = df.reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['Name', 'Type', 'MapRequired', 'Acts'], dtype='object')

# %%
df['Type'].value_counts()
# Out:
# Type
# Map Raid      10
# Story          9
# Map Legend     6
# Map Rift       6
# Dungeon        2
# Name: count, dtype: int64
