# %%
import pandas as pd
import json

# %%
with open(r'C:\Users\USER\Desktop\Programming\Python\Personal_Projects\Anime Royale Wiki\ar_wiki\data\cleaned_data\maps.json', 'r') as f:
    item_data = json.load(f)

# %%
df = pd.DataFrame.from_dict(item_data, orient="index")
df = df.reset_index(drop=True)

# %%
df
# Out:
#                       Name        Type      MapRequired  \
# 0        Christmas Village  Map Legend             None
# 1          Fairy Town Rift     Dungeon       Fairy Town
# 2                Aura Room    Map Raid             None
# 3       Blue Flower Forest  Map Legend             None
# 4     The Underground Tomb    Map Raid             None
# 5           Haunted Circus  Map Legend             None
# 6                Corp City       Story             None
# 7               Soul World       Story             None
# 8   Green Planet Destroyed    Map Raid             None
# 9               Fairy Town       Story             None
# 10              Red Palace    Map Raid             None
# 11         Sharkman Island       Story             None
# 12                 Lookout    Map Raid             None
# 13             Cursed Town       Story             None
# 14        Slayers District    Map Raid             None
# 15            Green Planet       Story             None
# 16             Boru's Room    Map Raid             None
# 17        Valentine Castle  Map Legend             None
# 18                    Hell  Map Legend             None
# 19        Strongest's City       Story             None
# 20     Hidden Village Rift    Map Rift   Hidden Village
# 21          Hidden Village       Story             None
# 22              Ant Island     Dungeon       Fairy Town
# 23              Ghoul City       Story             None
# 24           Hollow Desert    Map Raid             None
# 25              God Statue    Map Rift       Fairy Town
# 26         Sorcery Academy    Map Raid             None
# 27             Orc Dungeon    Map Rift       Fairy Town
# 28       Green Planet Rift    Map Rift     Green Planet
# 29    Sharkman Island Rift    Map Rift  Sharkman Island
# 30              Candy Park    Map Raid             None
# 31             Shadow City  Map Legend             None
# 32         Ghoul City Rift    Map Rift       Ghoul City
#
#                                                  Acts
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   [Buldo's Mind Binds!, Jest Battle Armor!, The ...
# 7   [Soul Muncher, Soul Muncher but strong, Soul M...
# 8                                                  []
# 9   [Virtual Swordman: The Black Swordsman's Judgm...
# 10                                                 []
# 11  [Bul bul bul!, Ble ble ble!, Bul bul bul!, Ble...
# 12                                                 []
# 13  [Nobaro: Nails of Retribution!, Megu: Shikigam...
# 14                                                 []
# 15  [Buldo's Mind Binds!, Jest Battle Armor!, The ...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19  [Speedy Sonic's Speeding Fate!, Gen Z's Unyiel...
# 20                                                 []
# 21  [Path One: The Judgement's Gaze!, Path Two: Th...
# 22                                                 []
# 23  [Wing Ghoul: The Silent Reaper!, Double Tails:...
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29                                                 []
# 30                                                 []
# 31                                                 []
# 32                                                 []
