# %%
import pandas as pd
import json

# %%
with open(r'C:\Users\USER\Desktop\Programming\Python\Personal_Projects\Anime Royale Wiki\ar_wiki\data\cleaned_data\dropdata.json', 'r') as f:
    item_data = json.load(f)

# %%
for key, value in item_data.items():
    if key == "Green Planet_5":
        for i,j in value['Difficulties'].items():
            print(j)
# Out:
# {'Items': {'Rerolls': {'Chance': 1.0, 'Amounts': {'1': 1.0}}, 'Scouter': {'Chance': 1.0, 'Amounts': {'1': 1.0}}, 'Radar': {'Chance': 1.0, 'Amounts': {'1': 1.0}}, 'Bean': {'Chance': 100.0, 'Amounts': {'1': 100.0, '2': 80.0, '3': 60.0, '4': 40.0, '5': 20.0}}, 'Apple': {'Chance': 100.0, 'Amounts': {'1': 100.0, '2': 80.0, '3': 60.0, '4': 40.0, '5': 20.0}}, 'Topaz': {'Chance': 30.0, 'Amounts': {'1': 30.0}}}, 'Units': {}}
# {'Items': {'Rerolls': {'Chance': 3.0, 'Amounts': {'1': 3.0}}, 'Scouter': {'Chance': 5.0, 'Amounts': {'1': 5.0}}, 'Radar': {'Chance': 5.0, 'Amounts': {'1': 5.0}}, 'Bean': {'Chance': 100.0, 'Amounts': {'1': 100.0, '2': 80.0, '3': 60.0, '4': 40.0, '5': 20.0}}, 'Apple': {'Chance': 100.0, 'Amounts': {'1': 100.0, '2': 80.0, '3': 60.0, '4': 40.0, '5': 20.0}}, 'Topaz': {'Chance': 50.0, 'Amounts': {'1': 50.0}}}, 'Units': {}}
# ...
