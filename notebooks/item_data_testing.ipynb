# %%
import pandas as pd
import json

# %%
with open(r'C:\Users\USER\Desktop\Programming\Python\Personal_Projects\Anime Royale Wiki\ar_wiki\data\cleaned_data\items.json', 'r') as f:
    item_data = json.load(f)

# %%
df = pd.DataFrame.from_dict(item_data, orient='index')
df = df.reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['Name', 'Class', 'Rarity', 'Description', 'CanTrade'], dtype='object')

# %%
df['Class'].value_counts()
# Out:
# Class
# Evo        101
# Card        22
# Misc        18
# Food        15
# Capsule      3
# Stat         2
# Stats        1
# Name: count, dtype: int64

# %%
df['Rarity'].value_counts()
# Out:
# Rarity
# Mythic       75
# Legendary    51
# Epic         14
# Rare         13
# Secret        9
# Name: count, dtype: int64
